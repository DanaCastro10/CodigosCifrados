# %% [markdown]
# <a href="https://colab.research.google.com/github/DanaCastro10/CodigosCifrados/blob/main/vigenerePropioINCOMPLETO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Analisis por sixgramas (letras)**

# %% [markdown]
# # Ataques estadisticos: Analisis de frecuencias

# %% [markdown]
# # # Funciones auxiliares

# %%
from collections import Counter
import pandas as pd

# %%
def encontrar_subcadenas_repetidas_desde_archivo(nombre_archivo, longitud_minima=4):

    try:
        with open(nombre_archivo, 'r') as archivo:
            texto_cifrado = archivo.read()
            n = len(texto_cifrado)
            frecuencia_subcadenas = {}

            if n < longitud_minima:
                return {}

            for longitud in range(longitud_minima, n // 2 + 1):
                for i in range(n - longitud + 1):
                    subcadena = texto_cifrado[i : i + longitud]
                    frecuencia_subcadenas[subcadena] = frecuencia_subcadenas.get(subcadena, 0) + 1

            subcadenas_repetidas = {sub: freq for sub, freq in frecuencia_subcadenas.items() if freq > 1}
            return subcadenas_repetidas
    except FileNotFoundError:
        print(f"Error: El archivo '{nombre_archivo}' no fue encontrado.")
        return {}
    except Exception as e:
        print(f"Ocurrió un error al leer el archivo: {e}")
        return {}

# Nombre del archivo de texto cifrado
nombre_archivo_cifrado = 'texto_cifrado.txt'

# Encontrar subcadenas repetidas de longitud mínima 2 desde el archivo
repeticiones = encontrar_subcadenas_repetidas_desde_archivo(nombre_archivo_cifrado)

# Mostrar las subcadenas repetidas y su frecuencia
if repeticiones:
    print("Análisis de Repeticiones del archivo:")
    for subcadena, frecuencia in sorted(repeticiones.items(), key=lambda item: item[1], reverse=True):
        print(f'  "{subcadena}" se repite {frecuencia} veces.')
else:
    print(f"No se encontraron subcadenas repetidas en el archivo '{nombre_archivo_cifrado}' o el archivo no pudo ser leído.")
# Out:
# Análisis de Repeticiones del archivo:
#   "WSNR" se repite 8 veces.
#   "SXZC" se repite 4 veces.
#   "LTEO" se repite 4 veces.
#   "WCVV" se repite 3 veces.
#   "ZTVW" se repite 3 veces.
#   "TEOG" se repite 3 veces.
#   "SHAK" se repite 3 veces.
#   "HAKE" se repite 3 veces.
#   "EIQT" se repite 3 veces.
#   "TLHG" se repite 3 veces.
#   "HWSN" se repite 3 veces.
#   "PEUW" se repite 3 veces.
#   "EUWE" se repite 3 veces.
#   "RGCI" se repite 3 veces.
#   "QQED" se repite 3 veces.
#   "QEDT" se repite 3 veces.
#   "QJGR" se repite 3 veces.
#   "FASX" se repite 3 veces.
#   "DTMI" se repite 3 veces.
#   "TMIU" se repite 3 veces.
#   "MIUK" se repite 3 veces.
#   "FVTP" se repite 3 veces.
#   "VAIH" se repite 3 veces.
#   "FVSX" se repite 3 veces.
#   "VSXG" se repite 3 veces.
#   "WQKS" se repite 3 veces.
#   "IUKI" se repite 3 veces.
#   "XGRF" se repite 3 veces.
#   "JRJX" se repite 3 veces.
#   "RJXT" se repite 3 veces.
#   "NRZT" se repite 3 veces.
#   "SHAKE" se repite 3 veces.
#   "PEUWE" se repite 3 veces.
#   "QQEDT" se repite 3 veces.
#   "DTMIU" se repite 3 veces.
#   "TMIUK" se repite 3 veces.
#   "JRJXT" se repite 3 veces.
#   "DTMIUK" se repite 3 veces.
#   "XZCT" se repite 2 veces.
#   "PKWS" se repite 2 veces.
#   "SXJG" se repite 2 veces.
#   "XJGK" se repite 2 veces.
#   "JGKC" se repite 2 veces.
#   "GKCH" se repite 2 veces.
#   "KCHM" se repite 2 veces.
#   "CHMO" se repite 2 veces.
#   "MHXZ" se repite 2 veces.
#   "XZNR" se repite 2 veces.
#   "UPUO" se repite 2 veces.
#   "OGCJ" se repite 2 veces.
#   "GCJP" se repite 2 veces.
#   "CJPK" se repite 2 veces.
#   "JPKF" se repite 2 veces.
#   "PKFK" se repite 2 veces.
#   "KFKF" se repite 2 veces.
#   "EOGE" se repite 2 veces.
#   "OGEK" se repite 2 veces.
#   "GEKX" se repite 2 veces.
#   "EKXF" se repite 2 veces.
#   "KXFO" se repite 2 veces.
#   "XFOF" se repite 2 veces.
#   "FOFR" se repite 2 veces.
#   "AKEI" se repite 2 veces.
#   "KEIQ" se repite 2 veces.
#   "UWTE" se repite 2 veces.
#   "DWVJ" se repite 2 veces.
#   "WVJA" se repite 2 veces.
#   "VJAH" se repite 2 veces.
#   "EWVA" se repite 2 veces.
#   "WVAT" se repite 2 veces.
#   "IXWC" se repite 2 veces.
#   "GJBX" se repite 2 veces.
#   "KOPU" se repite 2 veces.
#   "ULLT" se repite 2 veces.
#   "LLTL" se repite 2 veces.
#   "LTLH" se repite 2 veces.
#   "LHGU" se repite 2 veces.
#   "GUMH" se repite 2 veces.
#   "MHWS" se repite 2 veces.
#   "CVVP" se repite 2 veces.
#   "VVPE" se repite 2 veces.
#   "VPEU" se repite 2 veces.
#   "UWEW" se repite 2 veces.
#   "WEWH" se repite 2 veces.
#   "SUUM" se repite 2 veces.
#   "FGJB" se repite 2 veces.
#   "DLRG" se repite 2 veces.
#   "PGHK" se repite 2 veces.
#   "TQQE" se repite 2 veces.
#   "XBVV" se repite 2 veces.
#   "TRQJ" se repite 2 veces.
#   "JGRH" se repite 2 veces.
#   "ZCVV" se repite 2 veces.
#   "CVVR" se repite 2 veces.
#   "VVRB" se repite 2 veces.
#   "VRBA" se repite 2 veces.
#   "RBAC" se repite 2 veces.
#   "BACU" se repite 2 veces.
#   "ACUI" se repite 2 veces.
#   "TKOG" se repite 2 veces.
#   "VDUZ" se repite 2 veces.
#   "DUZG" se repite 2 veces.
#   "ICDI" se repite 2 veces.
#   "CDIM" se repite 2 veces.
#   "NZVP" se repite 2 veces.
#   "ZVPC" se repite 2 veces.
#   "VPCI" se repite 2 veces.
#   "PCIF" se repite 2 veces.
#   "CIFF" se repite 2 veces.
#   "IAEW" se repite 2 veces.
#   "HGCJ" se repite 2 veces.
#   "UKMC" se repite 2 veces.
#   "ISXZ" se repite 2 veces.
#   "VLWH" se repite 2 veces.
#   "WHXG" se repite 2 veces.
#   "HXGV" se repite 2 veces.
#   "GQTW" se repite 2 veces.
#   "QTWO" se repite 2 veces.
#   "TWOF" se repite 2 veces.
#   "HXFC" se repite 2 veces.
#   "OTKM" se repite 2 veces.
#   "CUMA" se repite 2 veces.
#   "UMAT" se repite 2 veces.
#   "RLTE" se repite 2 veces.
#   "FCCW" se repite 2 veces.
#   "XGCE" se repite 2 veces.
#   "PFOT" se repite 2 veces.
#   "GHRG" se repite 2 veces.
#   "HRGJ" se repite 2 veces.
#   "TGFF" se repite 2 veces.
#   "ORAX" se repite 2 veces.
#   "GFVT" se repite 2 veces.
#   "HRGC" se repite 2 veces.
#   "AIHR" se repite 2 veces.
#   "GTIH" se repite 2 veces.
#   "MHVC" se repite 2 veces.
#   "CJLT" se repite 2 veces.
#   "KXHG" se repite 2 veces.
#   "EFVK" se repite 2 veces.
#   "FVKX" se repite 2 veces.
#   "VKXB" se repite 2 veces.
#   "KXBV" se repite 2 veces.
#   "GFFV" se repite 2 veces.
#   "FFVS" se repite 2 veces.
#   "SXGG" se repite 2 veces.
#   "QTZC" se repite 2 veces.
#   "TZCG" se repite 2 veces.
#   "TRQG" se repite 2 veces.
#   "GWQK" se repite 2 veces.
#   "SIGK" se repite 2 veces.
#   "IGKW" se repite 2 veces.
#   "VTEQ" se repite 2 veces.
#   "TEQC" se repite 2 veces.
#   "DXDW" se repite 2 veces.
#   "XDWS" se repite 2 veces.
#   "DWSN" se repite 2 veces.
#   "WSNJ" se repite 2 veces.
#   "OUVV" se repite 2 veces.
#   "GXRG" se repite 2 veces.
#   "XRGU" se repite 2 veces.
#   "RGUW" se repite 2 veces.
#   "GUWG" se repite 2 veces.
#   "SNRA" se repite 2 veces.
#   "NRAR" se repite 2 veces.
#   "PPUW" se repite 2 veces.
#   "PUWC" se repite 2 veces.
#   "GJLT" se repite 2 veces.
#   "JLTE" se repite 2 veces.
#   "AIHF" se repite 2 veces.
#   "HTGJ" se repite 2 veces.
#   "TGJL" se repite 2 veces.
#   "TVWC" se repite 2 veces.
#   "LMAE" se repite 2 veces.
#   "MAEO" se repite 2 veces.
#   "AEOU" se repite 2 veces.
#   "KIAX" se repite 2 veces.
#   "IAXG" se repite 2 veces.
#   "AXGR" se repite 2 veces.
#   "PWSN" se repite 2 veces.
#   "HGRR" se repite 2 veces.
#   "HCTE" se repite 2 veces.
#   "EOGJ" se repite 2 veces.
#   "OGJK" se repite 2 veces.
#   "GJKD" se repite 2 veces.
#   "JKDU" se repite 2 veces.
#   "KDUO" se repite 2 veces.
#   "RYJX" se repite 2 veces.
#   "YJXZ" se repite 2 veces.
#   "UUMA" se repite 2 veces.
#   "TPLS" se repite 2 veces.
#   "TRCJ" se repite 2 veces.
#   "XZTV" se repite 2 veces.
#   "FVDT" se repite 2 veces.
#   "VDTM" se repite 2 veces.
#   "CEBT" se repite 2 veces.
#   "EDTG" se repite 2 veces.
#   "DTGH" se repite 2 veces.
#   "TGHQ" se repite 2 veces.
#   "BTWS" se repite 2 veces.
#   "TWSN" se repite 2 veces.
#   "SNRZ" se repite 2 veces.
#   "XBVR" se repite 2 veces.
#   "RZTO" se repite 2 veces.
#   "ZTOC" se repite 2 veces.
#   "TOCN" se repite 2 veces.
#   "OCNL" se repite 2 veces.
#   "CNLK" se repite 2 veces.
#   "NLKX" se repite 2 veces.
#   "LKXH" se repite 2 veces.
#   "KXHB" se repite 2 veces.
#   "HBFV" se repite 2 veces.
#   "ITFA" se repite 2 veces.
#   "IRBC" se repite 2 veces.
#   "RBCP" se repite 2 veces.
#   "CKDG" se repite 2 veces.
#   "XZGJ" se repite 2 veces.
#   "NXVW" se repite 2 veces.
#   "CJIC" se repite 2 veces.
#   "ASXZ" se repite 2 veces.
#   "BVVA" se repite 2 veces.
#   "OEFV" se repite 2 veces.
#   "TESF" se repite 2 veces.
#   "RJPX" se repite 2 veces.
#   "JPXZ" se repite 2 veces.
#   "KDGG" se repite 2 veces.
#   "XGFV" se repite 2 veces.
#   "SXZCT" se repite 2 veces.
#   "SXJGK" se repite 2 veces.
#   "XJGKC" se repite 2 veces.
#   "JGKCH" se repite 2 veces.
#   "GKCHM" se repite 2 veces.
#   "KCHMO" se repite 2 veces.
#   "OGCJP" se repite 2 veces.
#   "GCJPK" se repite 2 veces.
#   "CJPKF" se repite 2 veces.
#   "JPKFK" se repite 2 veces.
#   "PKFKF" se repite 2 veces.
#   "LTEOG" se repite 2 veces.
#   "TEOGE" se repite 2 veces.
#   "EOGEK" se repite 2 veces.
#   "OGEKX" se repite 2 veces.
#   "GEKXF" se repite 2 veces.
#   "EKXFO" se repite 2 veces.
#   "KXFOF" se repite 2 veces.
#   "XFOFR" se repite 2 veces.
#   "HAKEI" se repite 2 veces.
#   "AKEIQ" se repite 2 veces.
#   "KEIQT" se repite 2 veces.
#   "DWVJA" se repite 2 veces.
#   "WVJAH" se repite 2 veces.
#   "EWVAT" se repite 2 veces.
#   "ULLTL" se repite 2 veces.
#   "LLTLH" se repite 2 veces.
#   "LTLHG" se repite 2 veces.
#   "TLHGU" se repite 2 veces.
#   "MHWSN" se repite 2 veces.
#   "HWSNR" se repite 2 veces.
#   "WCVVP" se repite 2 veces.
#   "CVVPE" se repite 2 veces.
#   "VVPEU" se repite 2 veces.
#   "VPEUW" se repite 2 veces.
#   "EUWEW" se repite 2 veces.
#   "UWEWH" se repite 2 veces.
#   "QJGRH" se repite 2 veces.
#   "ZCVVR" se repite 2 veces.
#   "CVVRB" se repite 2 veces.
#   "VVRBA" se repite 2 veces.
#   "VRBAC" se repite 2 veces.
#   "RBACU" se repite 2 veces.
#   "BACUI" se repite 2 veces.
#   "VDUZG" se repite 2 veces.
#   "ICDIM" se repite 2 veces.
#   "NZVPC" se repite 2 veces.
#   "ZVPCI" se repite 2 veces.
#   "VPCIF" se repite 2 veces.
#   "PCIFF" se repite 2 veces.
#   "ISXZC" se repite 2 veces.
#   "WHXGV" se repite 2 veces.
#   "GQTWO" se repite 2 veces.
#   "QTWOF" se repite 2 veces.
#   "RLTEO" se repite 2 veces.
#   "GHRGJ" se repite 2 veces.
#   "GFVTP" se repite 2 veces.
#   "HRGCI" se repite 2 veces.
#   "VAIHR" se repite 2 veces.
#   "EFVKX" se repite 2 veces.
#   "FVKXB" se repite 2 veces.
#   "VKXBV" se repite 2 veces.
#   "GFFVS" se repite 2 veces.
#   "FFVSX" se repite 2 veces.
#   "FVSXG" se repite 2 veces.
#   "VSXGG" se repite 2 veces.
#   "GWQKS" se repite 2 veces.
#   "SIGKW" se repite 2 veces.
#   "VTEQC" se repite 2 veces.
#   "DXDWS" se repite 2 veces.
#   "XDWSN" se repite 2 veces.
#   "GXRGU" se repite 2 veces.
#   "XRGUW" se repite 2 veces.
#   "RGUWG" se repite 2 veces.
#   "WSNRA" se repite 2 veces.
#   "SNRAR" se repite 2 veces.
#   "PPUWC" se repite 2 veces.
#   "ZTVWC" se repite 2 veces.
#   "LMAEO" se repite 2 veces.
#   "MAEOU" se repite 2 veces.
#   "EOGJK" se repite 2 veces.
#   "OGJKD" se repite 2 veces.
#   "GJKDU" se repite 2 veces.
#   "JKDUO" se repite 2 veces.
#   "FVDTM" se repite 2 veces.
#   "VDTMI" se repite 2 veces.
#   "MIUKI" se repite 2 veces.
#   "QEDTG" se repite 2 veces.
#   "EDTGH" se repite 2 veces.
#   "DTGHQ" se repite 2 veces.
#   "BTWSN" se repite 2 veces.
#   "WSNRZ" se repite 2 veces.
#   "SNRZT" se repite 2 veces.
#   "NRZTO" se repite 2 veces.
#   "RZTOC" se repite 2 veces.
#   "ZTOCN" se repite 2 veces.
#   "TOCNL" se repite 2 veces.
#   "OCNLK" se repite 2 veces.
#   "CNLKX" se repite 2 veces.
#   "NLKXH" se repite 2 veces.
#   "LKXHB" se repite 2 veces.
#   "IRBCP" se repite 2 veces.
#   "RJPXZ" se repite 2 veces.
#   "SXJGKC" se repite 2 veces.
#   "XJGKCH" se repite 2 veces.
#   "JGKCHM" se repite 2 veces.
#   "GKCHMO" se repite 2 veces.
#   "OGCJPK" se repite 2 veces.
#   "GCJPKF" se repite 2 veces.
#   "CJPKFK" se repite 2 veces.
#   "JPKFKF" se repite 2 veces.
#   "LTEOGE" se repite 2 veces.
#   "TEOGEK" se repite 2 veces.
#   "EOGEKX" se repite 2 veces.
#   "OGEKXF" se repite 2 veces.
#   "GEKXFO" se repite 2 veces.
#   "EKXFOF" se repite 2 veces.
#   "KXFOFR" se repite 2 veces.
#   "SHAKEI" se repite 2 veces.
#   "HAKEIQ" se repite 2 veces.
#   "AKEIQT" se repite 2 veces.
#   "DWVJAH" se repite 2 veces.
#   "ULLTLH" se repite 2 veces.
#   "LLTLHG" se repite 2 veces.
#   "LTLHGU" se repite 2 veces.
#   "WCVVPE" se repite 2 veces.
#   "CVVPEU" se repite 2 veces.
#   "VVPEUW" se repite 2 veces.
#   "VPEUWE" se repite 2 veces.
#   "PEUWEW" se repite 2 veces.
#   "EUWEWH" se repite 2 veces.
#   "ZCVVRB" se repite 2 veces.
#   "CVVRBA" se repite 2 veces.
#   "VVRBAC" se repite 2 veces.
#   "VRBACU" se repite 2 veces.
#   "RBACUI" se repite 2 veces.
#   "NZVPCI" se repite 2 veces.
#   "ZVPCIF" se repite 2 veces.
#   "VPCIFF" se repite 2 veces.
#   "GQTWOF" se repite 2 veces.
#   "EFVKXB" se repite 2 veces.
#   "FVKXBV" se repite 2 veces.
#   "GFFVSX" se repite 2 veces.
#   "FFVSXG" se repite 2 veces.
#   "FVSXGG" se repite 2 veces.
#   "DXDWSN" se repite 2 veces.
#   "GXRGUW" se repite 2 veces.
#   "XRGUWG" se repite 2 veces.
#   "WSNRAR" se repite 2 veces.
#   "LMAEOU" se repite 2 veces.
#   "EOGJKD" se repite 2 veces.
#   "OGJKDU" se repite 2 veces.
#   "GJKDUO" se repite 2 veces.
#   "FVDTMI" se repite 2 veces.
#   "VDTMIU" se repite 2 veces.
#   "TMIUKI" se repite 2 veces.
#   "QQEDTG" se repite 2 veces.
#   "QEDTGH" se repite 2 veces.
#   "EDTGHQ" se repite 2 veces.
#   "WSNRZT" se repite 2 veces.
#   "NRZTOC" se repite 2 veces.
#   "RZTOCN" se repite 2 veces.
#   "ZTOCNL" se repite 2 veces.
#   "TOCNLK" se repite 2 veces.
#   "OCNLKX" se repite 2 veces.
#   "CNLKXH" se repite 2 veces.
#   "NLKXHB" se repite 2 veces.
#   "SXJGKCH" se repite 2 veces.
#   "XJGKCHM" se repite 2 veces.
#   "JGKCHMO" se repite 2 veces.
#   "OGCJPKF" se repite 2 veces.
#   "GCJPKFK" se repite 2 veces.
#   "CJPKFKF" se repite 2 veces.
#   "LTEOGEK" se repite 2 veces.
#   "TEOGEKX" se repite 2 veces.
#   "EOGEKXF" se repite 2 veces.
#   "OGEKXFO" se repite 2 veces.
#   "GEKXFOF" se repite 2 veces.
#   "EKXFOFR" se repite 2 veces.
#   "SHAKEIQ" se repite 2 veces.
#   "HAKEIQT" se repite 2 veces.
#   "ULLTLHG" se repite 2 veces.
#   "LLTLHGU" se repite 2 veces.
#   "WCVVPEU" se repite 2 veces.
#   "CVVPEUW" se repite 2 veces.
#   "VVPEUWE" se repite 2 veces.
#   "PEUWEWH" se repite 2 veces.
#   "ZCVVRBA" se repite 2 veces.
#   "CVVRBAC" se repite 2 veces.
#   "VVRBACU" se repite 2 veces.
#   "VRBACUI" se repite 2 veces.
#   "NZVPCIF" se repite 2 veces.
#   "ZVPCIFF" se repite 2 veces.
#   "EFVKXBV" se repite 2 veces.
#   "GFFVSXG" se repite 2 veces.
#   "FFVSXGG" se repite 2 veces.
#   "GXRGUWG" se repite 2 veces.
#   "EOGJKDU" se repite 2 veces.
#   "OGJKDUO" se repite 2 veces.
#   "FVDTMIU" se repite 2 veces.
#   "VDTMIUK" se repite 2 veces.
#   "DTMIUKI" se repite 2 veces.
#   "QQEDTGH" se repite 2 veces.
#   "QEDTGHQ" se repite 2 veces.
#   "NRZTOCN" se repite 2 veces.
#   "RZTOCNL" se repite 2 veces.
#   "ZTOCNLK" se repite 2 veces.
#   "TOCNLKX" se repite 2 veces.
#   "OCNLKXH" se repite 2 veces.
#   "CNLKXHB" se repite 2 veces.
#   "SXJGKCHM" se repite 2 veces.
#   "XJGKCHMO" se repite 2 veces.
#   "OGCJPKFK" se repite 2 veces.
#   "GCJPKFKF" se repite 2 veces.
#   "LTEOGEKX" se repite 2 veces.
#   "TEOGEKXF" se repite 2 veces.
#   "EOGEKXFO" se repite 2 veces.
#   "OGEKXFOF" se repite 2 veces.
#   "GEKXFOFR" se repite 2 veces.
#   "SHAKEIQT" se repite 2 veces.
#   "ULLTLHGU" se repite 2 veces.
#   "WCVVPEUW" se repite 2 veces.
#   "CVVPEUWE" se repite 2 veces.
#   "ZCVVRBAC" se repite 2 veces.
#   "CVVRBACU" se repite 2 veces.
#   "VVRBACUI" se repite 2 veces.
#   "NZVPCIFF" se repite 2 veces.
#   "GFFVSXGG" se repite 2 veces.
#   "EOGJKDUO" se repite 2 veces.
#   "FVDTMIUK" se repite 2 veces.
#   "VDTMIUKI" se repite 2 veces.
#   "QQEDTGHQ" se repite 2 veces.
#   "NRZTOCNL" se repite 2 veces.
#   "RZTOCNLK" se repite 2 veces.
#   "ZTOCNLKX" se repite 2 veces.
#   "TOCNLKXH" se repite 2 veces.
#   "OCNLKXHB" se repite 2 veces.
#   "SXJGKCHMO" se repite 2 veces.
#   "OGCJPKFKF" se repite 2 veces.
#   "LTEOGEKXF" se repite 2 veces.
#   "TEOGEKXFO" se repite 2 veces.
#   "EOGEKXFOF" se repite 2 veces.
#   "OGEKXFOFR" se repite 2 veces.
#   "WCVVPEUWE" se repite 2 veces.
#   "ZCVVRBACU" se repite 2 veces.
#   "CVVRBACUI" se repite 2 veces.
#   "FVDTMIUKI" se repite 2 veces.
#   "NRZTOCNLK" se repite 2 veces.
#   "RZTOCNLKX" se repite 2 veces.
#   "ZTOCNLKXH" se repite 2 veces.
#   "TOCNLKXHB" se repite 2 veces.
#   "LTEOGEKXFO" se repite 2 veces.
#   "TEOGEKXFOF" se repite 2 veces.
#   "EOGEKXFOFR" se repite 2 veces.
#   "ZCVVRBACUI" se repite 2 veces.
#   "NRZTOCNLKX" se repite 2 veces.
#   "RZTOCNLKXH" se repite 2 veces.
#   "ZTOCNLKXHB" se repite 2 veces.
#   "LTEOGEKXFOF" se repite 2 veces.
#   "TEOGEKXFOFR" se repite 2 veces.
#   "NRZTOCNLKXH" se repite 2 veces.
#   "RZTOCNLKXHB" se repite 2 veces.
#   "LTEOGEKXFOFR" se repite 2 veces.
#   "NRZTOCNLKXHB" se repite 2 veces.

# %% [markdown]
# **Usamos el ngrama con mas coincidencias**

# %%
def encontrar_repeticiones_con_distancia(nombre_archivo, longitud_minima=4):

    try:
        with open(nombre_archivo, 'r') as archivo:
            texto_cifrado = archivo.read()
            n = len(texto_cifrado)
            repeticiones_con_distancia = {}

            if n < longitud_minima:
                return {}

            for longitud in range(longitud_minima, n // 2 + 1):
                ocurrencias = {}  # Diccionario para almacenar las ocurrencias de cada subcadena de la longitud actual
                for i in range(n - longitud + 1):
                    subcadena = texto_cifrado[i : i + longitud]
                    if subcadena in ocurrencias:
                        ocurrencias[subcadena].append(i)
                    else:
                        ocurrencias[subcadena] = [i]

                for subcadena, indices in ocurrencias.items():
                    if len(indices) > 1:
                        distancias = []
                        for j in range(len(indices) - 1):
                            distancias.append(indices[j+1] - indices[j])
                        repeticiones_con_distancia[subcadena] = distancias

            return repeticiones_con_distancia

    except FileNotFoundError:
        print(f"Error: El archivo '{nombre_archivo}' no fue encontrado.")
        return {}
    except Exception as e:
        print(f"Ocurrió un error al leer el archivo: {e}")
        return {}

# Nombre del archivo de texto cifrado
nombre_archivo_cifrado = 'texto_cifrado.txt'

# Encontrar repeticiones con la distancia entre sus ocurrencias
resultados_con_distancia = encontrar_repeticiones_con_distancia(nombre_archivo_cifrado)

# Mostrar los resultados
if resultados_con_distancia:
    print("Análisis de Repeticiones con Distancia:")
    for subcadena, distancias in sorted(resultados_con_distancia.items(), key=lambda item: len(item[1]), reverse=True):
        print(f'  Subcadena: "{subcadena}"')
        print(f'    Distancias entre ocurrencias consecutivas: {distancias}')
else:
    print(f"No se encontraron subcadenas repetidas en el archivo '{nombre_archivo_cifrado}' o el archivo no pudo ser leído.")
# Out:
# Análisis de Repeticiones con Distancia:
#   Subcadena: "WSNR"
#     Distancias entre ocurrencias consecutivas: [792, 54, 246, 402, 12, 66, 1032]
#   Subcadena: "SXZC"
#     Distancias entre ocurrencias consecutivas: [480, 1134, 336]
#   Subcadena: "LTEO"
#     Distancias entre ocurrencias consecutivas: [498, 486, 420]
#   Subcadena: "WCVV"
#     Distancias entre ocurrencias consecutivas: [168, 942]
#   Subcadena: "ZTVW"
#     Distancias entre ocurrencias consecutivas: [1080, 174]
#   Subcadena: "TEOG"
#     Distancias entre ocurrencias consecutivas: [984, 228]
#   Subcadena: "SHAK"
#     Distancias entre ocurrencias consecutivas: [1068, 462]
#   Subcadena: "HAKE"
#     Distancias entre ocurrencias consecutivas: [1068, 462]
#   Subcadena: "EIQT"
#     Distancias entre ocurrencias consecutivas: [750, 318]
#   Subcadena: "TLHG"
#     Distancias entre ocurrencias consecutivas: [792, 1392]
#   Subcadena: "HWSN"
#     Distancias entre ocurrencias consecutivas: [1110, 1494]
#   Subcadena: "PEUW"
#     Distancias entre ocurrencias consecutivas: [300, 642]
#   Subcadena: "EUWE"
#     Distancias entre ocurrencias consecutivas: [300, 642]
#   Subcadena: "RGCI"
#     Distancias entre ocurrencias consecutivas: [480, 1314]
#   Subcadena: "QQED"
#     Distancias entre ocurrencias consecutivas: [1332, 234]
#   Subcadena: "QEDT"
#     Distancias entre ocurrencias consecutivas: [1332, 234]
#   Subcadena: "QJGR"
#     Distancias entre ocurrencias consecutivas: [2460, 48]
#   Subcadena: "FASX"
#     Distancias entre ocurrencias consecutivas: [1728, 78]
#   Subcadena: "DTMI"
#     Distancias entre ocurrencias consecutivas: [1098, 846]
#   Subcadena: "TMIU"
#     Distancias entre ocurrencias consecutivas: [1098, 846]
#   Subcadena: "MIUK"
#     Distancias entre ocurrencias consecutivas: [1098, 846]
#   Subcadena: "FVTP"
#     Distancias entre ocurrencias consecutivas: [666, 1044]
#   Subcadena: "VAIH"
#     Distancias entre ocurrencias consecutivas: [1380, 6]
#   Subcadena: "FVSX"
#     Distancias entre ocurrencias consecutivas: [870, 414]
#   Subcadena: "VSXG"
#     Distancias entre ocurrencias consecutivas: [870, 810]
#   Subcadena: "WQKS"
#     Distancias entre ocurrencias consecutivas: [1230, 540]
#   Subcadena: "IUKI"
#     Distancias entre ocurrencias consecutivas: [570, 846]
#   Subcadena: "XGRF"
#     Distancias entre ocurrencias consecutivas: [1008, 510]
#   Subcadena: "JRJX"
#     Distancias entre ocurrencias consecutivas: [618, 498]
#   Subcadena: "RJXT"
#     Distancias entre ocurrencias consecutivas: [618, 498]
#   Subcadena: "NRZT"
#     Distancias entre ocurrencias consecutivas: [78, 786]
#   Subcadena: "SHAKE"
#     Distancias entre ocurrencias consecutivas: [1068, 462]
#   Subcadena: "PEUWE"
#     Distancias entre ocurrencias consecutivas: [300, 642]
#   Subcadena: "QQEDT"
#     Distancias entre ocurrencias consecutivas: [1332, 234]
#   Subcadena: "DTMIU"
#     Distancias entre ocurrencias consecutivas: [1098, 846]
#   Subcadena: "TMIUK"
#     Distancias entre ocurrencias consecutivas: [1098, 846]
#   Subcadena: "JRJXT"
#     Distancias entre ocurrencias consecutivas: [618, 498]
#   Subcadena: "DTMIUK"
#     Distancias entre ocurrencias consecutivas: [1098, 846]
#   Subcadena: "XZCT"
#     Distancias entre ocurrencias consecutivas: [1950]
#   Subcadena: "PKWS"
#     Distancias entre ocurrencias consecutivas: [1584]
#   Subcadena: "SXJG"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "XJGK"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "JGKC"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "GKCH"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "KCHM"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "CHMO"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "MHXZ"
#     Distancias entre ocurrencias consecutivas: [678]
#   Subcadena: "XZNR"
#     Distancias entre ocurrencias consecutivas: [1290]
#   Subcadena: "UPUO"
#     Distancias entre ocurrencias consecutivas: [426]
#   Subcadena: "OGCJ"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "GCJP"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "CJPK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "JPKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "PKFK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "KFKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "EOGE"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "OGEK"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "GEKX"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EKXF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "KXFO"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "XFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "FOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "AKEI"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "KEIQ"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "UWTE"
#     Distancias entre ocurrencias consecutivas: [2562]
#   Subcadena: "DWVJ"
#     Distancias entre ocurrencias consecutivas: [912]
#   Subcadena: "WVJA"
#     Distancias entre ocurrencias consecutivas: [912]
#   Subcadena: "VJAH"
#     Distancias entre ocurrencias consecutivas: [912]
#   Subcadena: "EWVA"
#     Distancias entre ocurrencias consecutivas: [564]
#   Subcadena: "WVAT"
#     Distancias entre ocurrencias consecutivas: [564]
#   Subcadena: "IXWC"
#     Distancias entre ocurrencias consecutivas: [1290]
#   Subcadena: "GJBX"
#     Distancias entre ocurrencias consecutivas: [2460]
#   Subcadena: "KOPU"
#     Distancias entre ocurrencias consecutivas: [678]
#   Subcadena: "ULLT"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LLTL"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LTLH"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LHGU"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "GUMH"
#     Distancias entre ocurrencias consecutivas: [114]
#   Subcadena: "MHWS"
#     Distancias entre ocurrencias consecutivas: [1110]
#   Subcadena: "CVVP"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "VVPE"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "VPEU"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "UWEW"
#     Distancias entre ocurrencias consecutivas: [300]
#   Subcadena: "WEWH"
#     Distancias entre ocurrencias consecutivas: [300]
#   Subcadena: "SUUM"
#     Distancias entre ocurrencias consecutivas: [1260]
#   Subcadena: "FGJB"
#     Distancias entre ocurrencias consecutivas: [2364]
#   Subcadena: "DLRG"
#     Distancias entre ocurrencias consecutivas: [1992]
#   Subcadena: "PGHK"
#     Distancias entre ocurrencias consecutivas: [396]
#   Subcadena: "TQQE"
#     Distancias entre ocurrencias consecutivas: [2058]
#   Subcadena: "XBVV"
#     Distancias entre ocurrencias consecutivas: [1884]
#   Subcadena: "TRQJ"
#     Distancias entre ocurrencias consecutivas: [180]
#   Subcadena: "JGRH"
#     Distancias entre ocurrencias consecutivas: [2508]
#   Subcadena: "ZCVV"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "CVVR"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VVRB"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VRBA"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "RBAC"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "BACU"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "ACUI"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "TKOG"
#     Distancias entre ocurrencias consecutivas: [228]
#   Subcadena: "VDUZ"
#     Distancias entre ocurrencias consecutivas: [366]
#   Subcadena: "DUZG"
#     Distancias entre ocurrencias consecutivas: [366]
#   Subcadena: "ICDI"
#     Distancias entre ocurrencias consecutivas: [924]
#   Subcadena: "CDIM"
#     Distancias entre ocurrencias consecutivas: [924]
#   Subcadena: "NZVP"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "ZVPC"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "VPCI"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "PCIF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "CIFF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "IAEW"
#     Distancias entre ocurrencias consecutivas: [1032]
#   Subcadena: "HGCJ"
#     Distancias entre ocurrencias consecutivas: [2046]
#   Subcadena: "UKMC"
#     Distancias entre ocurrencias consecutivas: [2196]
#   Subcadena: "ISXZ"
#     Distancias entre ocurrencias consecutivas: [1134]
#   Subcadena: "VLWH"
#     Distancias entre ocurrencias consecutivas: [606]
#   Subcadena: "WHXG"
#     Distancias entre ocurrencias consecutivas: [1716]
#   Subcadena: "HXGV"
#     Distancias entre ocurrencias consecutivas: [1716]
#   Subcadena: "GQTW"
#     Distancias entre ocurrencias consecutivas: [1908]
#   Subcadena: "QTWO"
#     Distancias entre ocurrencias consecutivas: [1908]
#   Subcadena: "TWOF"
#     Distancias entre ocurrencias consecutivas: [1908]
#   Subcadena: "HXFC"
#     Distancias entre ocurrencias consecutivas: [684]
#   Subcadena: "OTKM"
#     Distancias entre ocurrencias consecutivas: [1338]
#   Subcadena: "CUMA"
#     Distancias entre ocurrencias consecutivas: [2160]
#   Subcadena: "UMAT"
#     Distancias entre ocurrencias consecutivas: [900]
#   Subcadena: "RLTE"
#     Distancias entre ocurrencias consecutivas: [906]
#   Subcadena: "FCCW"
#     Distancias entre ocurrencias consecutivas: [1518]
#   Subcadena: "XGCE"
#     Distancias entre ocurrencias consecutivas: [1266]
#   Subcadena: "PFOT"
#     Distancias entre ocurrencias consecutivas: [1590]
#   Subcadena: "GHRG"
#     Distancias entre ocurrencias consecutivas: [1290]
#   Subcadena: "HRGJ"
#     Distancias entre ocurrencias consecutivas: [1290]
#   Subcadena: "TGFF"
#     Distancias entre ocurrencias consecutivas: [1080]
#   Subcadena: "ORAX"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "GFVT"
#     Distancias entre ocurrencias consecutivas: [1710]
#   Subcadena: "HRGC"
#     Distancias entre ocurrencias consecutivas: [1314]
#   Subcadena: "AIHR"
#     Distancias entre ocurrencias consecutivas: [1380]
#   Subcadena: "GTIH"
#     Distancias entre ocurrencias consecutivas: [456]
#   Subcadena: "MHVC"
#     Distancias entre ocurrencias consecutivas: [36]
#   Subcadena: "CJLT"
#     Distancias entre ocurrencias consecutivas: [1854]
#   Subcadena: "KXHG"
#     Distancias entre ocurrencias consecutivas: [486]
#   Subcadena: "EFVK"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "FVKX"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "VKXB"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "KXBV"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "GFFV"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "FFVS"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "SXGG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "QTZC"
#     Distancias entre ocurrencias consecutivas: [282]
#   Subcadena: "TZCG"
#     Distancias entre ocurrencias consecutivas: [1566]
#   Subcadena: "TRQG"
#     Distancias entre ocurrencias consecutivas: [1680]
#   Subcadena: "GWQK"
#     Distancias entre ocurrencias consecutivas: [1770]
#   Subcadena: "SIGK"
#     Distancias entre ocurrencias consecutivas: [1422]
#   Subcadena: "IGKW"
#     Distancias entre ocurrencias consecutivas: [1422]
#   Subcadena: "VTEQ"
#     Distancias entre ocurrencias consecutivas: [1326]
#   Subcadena: "TEQC"
#     Distancias entre ocurrencias consecutivas: [1326]
#   Subcadena: "DXDW"
#     Distancias entre ocurrencias consecutivas: [798]
#   Subcadena: "XDWS"
#     Distancias entre ocurrencias consecutivas: [798]
#   Subcadena: "DWSN"
#     Distancias entre ocurrencias consecutivas: [798]
#   Subcadena: "WSNJ"
#     Distancias entre ocurrencias consecutivas: [1032]
#   Subcadena: "OUVV"
#     Distancias entre ocurrencias consecutivas: [156]
#   Subcadena: "GXRG"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "XRGU"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "RGUW"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "GUWG"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "SNRA"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "NRAR"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "PPUW"
#     Distancias entre ocurrencias consecutivas: [1512]
#   Subcadena: "PUWC"
#     Distancias entre ocurrencias consecutivas: [1512]
#   Subcadena: "GJLT"
#     Distancias entre ocurrencias consecutivas: [708]
#   Subcadena: "JLTE"
#     Distancias entre ocurrencias consecutivas: [1578]
#   Subcadena: "AIHF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "HTGJ"
#     Distancias entre ocurrencias consecutivas: [936]
#   Subcadena: "TGJL"
#     Distancias entre ocurrencias consecutivas: [282]
#   Subcadena: "TVWC"
#     Distancias entre ocurrencias consecutivas: [174]
#   Subcadena: "LMAE"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "MAEO"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "AEOU"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "KIAX"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "IAXG"
#     Distancias entre ocurrencias consecutivas: [1170]
#   Subcadena: "AXGR"
#     Distancias entre ocurrencias consecutivas: [1530]
#   Subcadena: "PWSN"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "HGRR"
#     Distancias entre ocurrencias consecutivas: [1464]
#   Subcadena: "HCTE"
#     Distancias entre ocurrencias consecutivas: [930]
#   Subcadena: "EOGJ"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "OGJK"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "GJKD"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "JKDU"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "KDUO"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "RYJX"
#     Distancias entre ocurrencias consecutivas: [504]
#   Subcadena: "YJXZ"
#     Distancias entre ocurrencias consecutivas: [1128]
#   Subcadena: "UUMA"
#     Distancias entre ocurrencias consecutivas: [1284]
#   Subcadena: "TPLS"
#     Distancias entre ocurrencias consecutivas: [336]
#   Subcadena: "TRCJ"
#     Distancias entre ocurrencias consecutivas: [930]
#   Subcadena: "XZTV"
#     Distancias entre ocurrencias consecutivas: [1284]
#   Subcadena: "FVDT"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "VDTM"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "CEBT"
#     Distancias entre ocurrencias consecutivas: [396]
#   Subcadena: "EDTG"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "DTGH"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "TGHQ"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "BTWS"
#     Distancias entre ocurrencias consecutivas: [312]
#   Subcadena: "TWSN"
#     Distancias entre ocurrencias consecutivas: [312]
#   Subcadena: "SNRZ"
#     Distancias entre ocurrencias consecutivas: [78]
#   Subcadena: "XBVR"
#     Distancias entre ocurrencias consecutivas: [912]
#   Subcadena: "RZTO"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "ZTOC"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "TOCN"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "OCNL"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "CNLK"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "NLKX"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "LKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "KXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "HBFV"
#     Distancias entre ocurrencias consecutivas: [660]
#   Subcadena: "ITFA"
#     Distancias entre ocurrencias consecutivas: [222]
#   Subcadena: "IRBC"
#     Distancias entre ocurrencias consecutivas: [618]
#   Subcadena: "RBCP"
#     Distancias entre ocurrencias consecutivas: [618]
#   Subcadena: "CKDG"
#     Distancias entre ocurrencias consecutivas: [288]
#   Subcadena: "XZGJ"
#     Distancias entre ocurrencias consecutivas: [558]
#   Subcadena: "NXVW"
#     Distancias entre ocurrencias consecutivas: [594]
#   Subcadena: "CJIC"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "ASXZ"
#     Distancias entre ocurrencias consecutivas: [684]
#   Subcadena: "BVVA"
#     Distancias entre ocurrencias consecutivas: [672]
#   Subcadena: "OEFV"
#     Distancias entre ocurrencias consecutivas: [264]
#   Subcadena: "TESF"
#     Distancias entre ocurrencias consecutivas: [444]
#   Subcadena: "RJPX"
#     Distancias entre ocurrencias consecutivas: [372]
#   Subcadena: "JPXZ"
#     Distancias entre ocurrencias consecutivas: [372]
#   Subcadena: "KDGG"
#     Distancias entre ocurrencias consecutivas: [126]
#   Subcadena: "XGFV"
#     Distancias entre ocurrencias consecutivas: [30]
#   Subcadena: "SXZCT"
#     Distancias entre ocurrencias consecutivas: [1950]
#   Subcadena: "SXJGK"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "XJGKC"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "JGKCH"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "GKCHM"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "KCHMO"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "OGCJP"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "GCJPK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "CJPKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "JPKFK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "PKFKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "LTEOG"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "TEOGE"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EOGEK"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "OGEKX"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "GEKXF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EKXFO"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "KXFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "XFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "HAKEI"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "AKEIQ"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "KEIQT"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "DWVJA"
#     Distancias entre ocurrencias consecutivas: [912]
#   Subcadena: "WVJAH"
#     Distancias entre ocurrencias consecutivas: [912]
#   Subcadena: "EWVAT"
#     Distancias entre ocurrencias consecutivas: [564]
#   Subcadena: "ULLTL"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LLTLH"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LTLHG"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "TLHGU"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "MHWSN"
#     Distancias entre ocurrencias consecutivas: [1110]
#   Subcadena: "HWSNR"
#     Distancias entre ocurrencias consecutivas: [2604]
#   Subcadena: "WCVVP"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "CVVPE"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "VVPEU"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "VPEUW"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "EUWEW"
#     Distancias entre ocurrencias consecutivas: [300]
#   Subcadena: "UWEWH"
#     Distancias entre ocurrencias consecutivas: [300]
#   Subcadena: "QJGRH"
#     Distancias entre ocurrencias consecutivas: [2508]
#   Subcadena: "ZCVVR"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "CVVRB"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VVRBA"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VRBAC"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "RBACU"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "BACUI"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VDUZG"
#     Distancias entre ocurrencias consecutivas: [366]
#   Subcadena: "ICDIM"
#     Distancias entre ocurrencias consecutivas: [924]
#   Subcadena: "NZVPC"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "ZVPCI"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "VPCIF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "PCIFF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "ISXZC"
#     Distancias entre ocurrencias consecutivas: [1134]
#   Subcadena: "WHXGV"
#     Distancias entre ocurrencias consecutivas: [1716]
#   Subcadena: "GQTWO"
#     Distancias entre ocurrencias consecutivas: [1908]
#   Subcadena: "QTWOF"
#     Distancias entre ocurrencias consecutivas: [1908]
#   Subcadena: "RLTEO"
#     Distancias entre ocurrencias consecutivas: [906]
#   Subcadena: "GHRGJ"
#     Distancias entre ocurrencias consecutivas: [1290]
#   Subcadena: "GFVTP"
#     Distancias entre ocurrencias consecutivas: [1710]
#   Subcadena: "HRGCI"
#     Distancias entre ocurrencias consecutivas: [1314]
#   Subcadena: "VAIHR"
#     Distancias entre ocurrencias consecutivas: [1380]
#   Subcadena: "EFVKX"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "FVKXB"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "VKXBV"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "GFFVS"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "FFVSX"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "FVSXG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "VSXGG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "GWQKS"
#     Distancias entre ocurrencias consecutivas: [1770]
#   Subcadena: "SIGKW"
#     Distancias entre ocurrencias consecutivas: [1422]
#   Subcadena: "VTEQC"
#     Distancias entre ocurrencias consecutivas: [1326]
#   Subcadena: "DXDWS"
#     Distancias entre ocurrencias consecutivas: [798]
#   Subcadena: "XDWSN"
#     Distancias entre ocurrencias consecutivas: [798]
#   Subcadena: "GXRGU"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "XRGUW"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "RGUWG"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "WSNRA"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "SNRAR"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "PPUWC"
#     Distancias entre ocurrencias consecutivas: [1512]
#   Subcadena: "ZTVWC"
#     Distancias entre ocurrencias consecutivas: [174]
#   Subcadena: "LMAEO"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "MAEOU"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "EOGJK"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "OGJKD"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "GJKDU"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "JKDUO"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "FVDTM"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "VDTMI"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "MIUKI"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "QEDTG"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "EDTGH"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "DTGHQ"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "BTWSN"
#     Distancias entre ocurrencias consecutivas: [312]
#   Subcadena: "WSNRZ"
#     Distancias entre ocurrencias consecutivas: [78]
#   Subcadena: "SNRZT"
#     Distancias entre ocurrencias consecutivas: [78]
#   Subcadena: "NRZTO"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "RZTOC"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "ZTOCN"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "TOCNL"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "OCNLK"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "CNLKX"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "NLKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "LKXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "IRBCP"
#     Distancias entre ocurrencias consecutivas: [618]
#   Subcadena: "RJPXZ"
#     Distancias entre ocurrencias consecutivas: [372]
#   Subcadena: "SXJGKC"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "XJGKCH"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "JGKCHM"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "GKCHMO"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "OGCJPK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "GCJPKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "CJPKFK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "JPKFKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "LTEOGE"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "TEOGEK"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EOGEKX"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "OGEKXF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "GEKXFO"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EKXFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "KXFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "SHAKEI"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "HAKEIQ"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "AKEIQT"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "DWVJAH"
#     Distancias entre ocurrencias consecutivas: [912]
#   Subcadena: "ULLTLH"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LLTLHG"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LTLHGU"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "WCVVPE"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "CVVPEU"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "VVPEUW"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "VPEUWE"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "PEUWEW"
#     Distancias entre ocurrencias consecutivas: [300]
#   Subcadena: "EUWEWH"
#     Distancias entre ocurrencias consecutivas: [300]
#   Subcadena: "ZCVVRB"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "CVVRBA"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VVRBAC"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VRBACU"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "RBACUI"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "NZVPCI"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "ZVPCIF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "VPCIFF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "GQTWOF"
#     Distancias entre ocurrencias consecutivas: [1908]
#   Subcadena: "EFVKXB"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "FVKXBV"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "GFFVSX"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "FFVSXG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "FVSXGG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "DXDWSN"
#     Distancias entre ocurrencias consecutivas: [798]
#   Subcadena: "GXRGUW"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "XRGUWG"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "WSNRAR"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "LMAEOU"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "EOGJKD"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "OGJKDU"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "GJKDUO"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "FVDTMI"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "VDTMIU"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "TMIUKI"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "QQEDTG"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "QEDTGH"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "EDTGHQ"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "WSNRZT"
#     Distancias entre ocurrencias consecutivas: [78]
#   Subcadena: "NRZTOC"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "RZTOCN"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "ZTOCNL"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "TOCNLK"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "OCNLKX"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "CNLKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "NLKXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "SXJGKCH"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "XJGKCHM"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "JGKCHMO"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "OGCJPKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "GCJPKFK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "CJPKFKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "LTEOGEK"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "TEOGEKX"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EOGEKXF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "OGEKXFO"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "GEKXFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EKXFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "SHAKEIQ"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "HAKEIQT"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "ULLTLHG"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "LLTLHGU"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "WCVVPEU"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "CVVPEUW"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "VVPEUWE"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "PEUWEWH"
#     Distancias entre ocurrencias consecutivas: [300]
#   Subcadena: "ZCVVRBA"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "CVVRBAC"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VVRBACU"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VRBACUI"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "NZVPCIF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "ZVPCIFF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "EFVKXBV"
#     Distancias entre ocurrencias consecutivas: [1650]
#   Subcadena: "GFFVSXG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "FFVSXGG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "GXRGUWG"
#     Distancias entre ocurrencias consecutivas: [1386]
#   Subcadena: "EOGJKDU"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "OGJKDUO"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "FVDTMIU"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "VDTMIUK"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "DTMIUKI"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "QQEDTGH"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "QEDTGHQ"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "NRZTOCN"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "RZTOCNL"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "ZTOCNLK"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "TOCNLKX"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "OCNLKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "CNLKXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "SXJGKCHM"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "XJGKCHMO"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "OGCJPKFK"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "GCJPKFKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "LTEOGEKX"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "TEOGEKXF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EOGEKXFO"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "OGEKXFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "GEKXFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "SHAKEIQT"
#     Distancias entre ocurrencias consecutivas: [1068]
#   Subcadena: "ULLTLHGU"
#     Distancias entre ocurrencias consecutivas: [792]
#   Subcadena: "WCVVPEUW"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "CVVPEUWE"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "ZCVVRBAC"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "CVVRBACU"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "VVRBACUI"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "NZVPCIFF"
#     Distancias entre ocurrencias consecutivas: [390]
#   Subcadena: "GFFVSXGG"
#     Distancias entre ocurrencias consecutivas: [870]
#   Subcadena: "EOGJKDUO"
#     Distancias entre ocurrencias consecutivas: [18]
#   Subcadena: "FVDTMIUK"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "VDTMIUKI"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "QQEDTGHQ"
#     Distancias entre ocurrencias consecutivas: [234]
#   Subcadena: "NRZTOCNL"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "RZTOCNLK"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "ZTOCNLKX"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "TOCNLKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "OCNLKXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "SXJGKCHMO"
#     Distancias entre ocurrencias consecutivas: [306]
#   Subcadena: "OGCJPKFKF"
#     Distancias entre ocurrencias consecutivas: [246]
#   Subcadena: "LTEOGEKXF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "TEOGEKXFO"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EOGEKXFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "OGEKXFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "WCVVPEUWE"
#     Distancias entre ocurrencias consecutivas: [942]
#   Subcadena: "ZCVVRBACU"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "CVVRBACUI"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "FVDTMIUKI"
#     Distancias entre ocurrencias consecutivas: [846]
#   Subcadena: "NRZTOCNLK"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "RZTOCNLKX"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "ZTOCNLKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "TOCNLKXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "LTEOGEKXFO"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "TEOGEKXFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "EOGEKXFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "ZCVVRBACUI"
#     Distancias entre ocurrencias consecutivas: [162]
#   Subcadena: "NRZTOCNLKX"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "RZTOCNLKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "ZTOCNLKXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "LTEOGEKXFOF"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "TEOGEKXFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "NRZTOCNLKXH"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "RZTOCNLKXHB"
#     Distancias entre ocurrencias consecutivas: [786]
#   Subcadena: "LTEOGEKXFOFR"
#     Distancias entre ocurrencias consecutivas: [984]
#   Subcadena: "NRZTOCNLKXHB"
#     Distancias entre ocurrencias consecutivas: [786]

# %%
import math

def calcular_mcd(lista_numeros):
    """Calcula el Máximo Común Divisor de una lista de números."""
    if not lista_numeros:
        return 0
    resultado = lista_numeros[0]
    for i in range(1, len(lista_numeros)):
        resultado = math.gcd(resultado, lista_numeros[i])
    return resultado

# Nombre del archivo de texto cifrado
nombre_archivo_cifrado = 'texto_cifrado.txt'

# Encontrar repeticiones con la distancia entre sus ocurrencias (ahora buscando desde longitud 2)
resultados_distancias = encontrar_repeticiones_con_distancia(nombre_archivo_cifrado, longitud_minima=4)

# Extraer todas las distancias en una sola lista
todas_las_distancias = []
for subcadena, distancias in resultados_distancias.items():
    todas_las_distancias.extend(distancias)

# Calcular el MCD de todas las distancias encontradas
mcd_distancias = calcular_mcd(todas_las_distancias)

print("Distancias encontradas:", todas_las_distancias)
print("El Máximo Común Divisor (MCD) de estas distancias es:", mcd_distancias)
print("Esto sugiere que la longitud de la clave es:", mcd_distancias)
# Out:
# Distancias encontradas: [480, 1134, 336, 1950, 168, 942, 1080, 174, 1584, 306, 306, 306, 306, 306, 306, 678, 1290, 426, 246, 246, 246, 246, 246, 246, 498, 486, 420, 984, 228, 984, 984, 984, 984, 984, 984, 984, 1068, 462, 1068, 462, 1068, 1068, 750, 318, 2562, 912, 912, 912, 564, 564, 1290, 2460, 678, 792, 792, 792, 792, 1392, 792, 114, 1110, 1110, 1494, 792, 54, 246, 402, 12, 66, 1032, 942, 942, 942, 300, 642, 300, 642, 300, 300, 1260, 2364, 1992, 480, 1314, 396, 2058, 1332, 234, 1332, 234, 1884, 180, 2460, 48, 2508, 162, 162, 162, 162, 162, 162, 162, 228, 366, 366, 924, 924, 390, 390, 390, 390, 390, 1032, 1728, 78, 2046, 1098, 846, 1098, 846, 1098, 846, 2196, 1134, 606, 1716, 1716, 1908, 1908, 1908, 684, 1338, 2160, 900, 906, 1518, 1266, 1590, 1290, 1290, 1080, 234, 1710, 666, 1044, 1314, 1380, 6, 1380, 456, 36, 1854, 486, 1650, 1650, 1650, 1650, 870, 870, 870, 414, 870, 810, 870, 282, 1566, 1680, 1770, 1230, 540, 1422, 1422, 1326, 1326, 798, 798, 798, 1032, 570, 846, 156, 1386, 1386, 1386, 1386, 246, 246, 1512, 1512, 708, 1578, 390, 936, 282, 174, 234, 234, 234, 1068, 1170, 1530, 1008, 510, 1068, 1464, 930, 18, 18, 18, 18, 18, 504, 1128, 618, 498, 618, 498, 1284, 336, 930, 1284, 846, 846, 396, 234, 234, 234, 312, 312, 78, 78, 786, 912, 786, 786, 786, 786, 786, 786, 786, 786, 660, 222, 618, 618, 288, 558, 594, 390, 684, 672, 264, 444, 372, 372, 126, 30, 1950, 306, 306, 306, 306, 306, 246, 246, 246, 246, 246, 984, 984, 984, 984, 984, 984, 984, 984, 1068, 462, 1068, 1068, 1068, 912, 912, 564, 792, 792, 792, 792, 1110, 2604, 942, 942, 942, 942, 300, 642, 300, 300, 1332, 234, 2508, 162, 162, 162, 162, 162, 162, 366, 924, 390, 390, 390, 390, 1098, 846, 1098, 846, 1134, 1716, 1908, 1908, 906, 1290, 1710, 1314, 1380, 1650, 1650, 1650, 870, 870, 870, 870, 1770, 1422, 1326, 798, 798, 1386, 1386, 1386, 246, 246, 1512, 174, 234, 234, 18, 18, 18, 18, 618, 498, 846, 846, 846, 234, 234, 234, 312, 78, 78, 786, 786, 786, 786, 786, 786, 786, 786, 618, 372, 306, 306, 306, 306, 246, 246, 246, 246, 984, 984, 984, 984, 984, 984, 984, 1068, 1068, 1068, 912, 792, 792, 792, 942, 942, 942, 942, 300, 300, 162, 162, 162, 162, 162, 390, 390, 390, 1098, 846, 1908, 1650, 1650, 870, 870, 870, 798, 1386, 1386, 246, 234, 18, 18, 18, 846, 846, 846, 234, 234, 234, 78, 786, 786, 786, 786, 786, 786, 786, 306, 306, 306, 246, 246, 246, 984, 984, 984, 984, 984, 984, 1068, 1068, 792, 792, 942, 942, 942, 300, 162, 162, 162, 162, 390, 390, 1650, 870, 870, 1386, 18, 18, 846, 846, 846, 234, 234, 786, 786, 786, 786, 786, 786, 306, 306, 246, 246, 984, 984, 984, 984, 984, 1068, 792, 942, 942, 162, 162, 162, 390, 870, 18, 846, 846, 234, 786, 786, 786, 786, 786, 306, 246, 984, 984, 984, 984, 942, 162, 162, 846, 786, 786, 786, 786, 984, 984, 984, 162, 786, 786, 786, 984, 984, 786, 786, 984, 786]
# El Máximo Común Divisor (MCD) de estas distancias es: 6
# Esto sugiere que la longitud de la clave es: 6

# %%
def dividir_en_subcriptogramas(texto_cifrado, longitud_clave,mcd_distancias):
    subcriptogramas = [''] * longitud_clave
    for i, letra in enumerate(texto_cifrado):
        indice_subcriptograma = i % longitud_clave
        subcriptogramas[indice_subcriptograma] += letra
    return subcriptogramas

# Nombre del archivo de texto cifrado
nombre_de_archivo_cifrado = 'texto_cifrado.txt'

# Leer el texto cifrado desde el archivo
try:
    with open(nombre_de_archivo_cifrado, 'r') as archivo:
        texto_cifrado_completo = archivo.read()
except FileNotFoundError:
    print(f"Error: El archivo '{nombre_de_archivo_cifrado}' no fue encontrado.")
    exit()
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {e}")
    exit()

# Longitud de la clave (determinada en el paso anterior)
longitud_clave_sugerida = mcd_distancias
# Dividir el texto cifrado en subcriptogramas
subcriptogramas_resultantes = dividir_en_subcriptogramas(texto_cifrado_completo, longitud_clave_sugerida, mcd_distancias)

# Imprimir los subcriptogramas
print(f"Dividiendo el texto cifrado en {longitud_clave_sugerida} subcriptogramas:\n")
for i, subcriptograma in enumerate(subcriptogramas_resultantes):
    print(f"Subcriptograma {i+1}: {subcriptograma}")
# Out:
# Dividiendo el texto cifrado en 6 subcriptogramas:
#
# Subcriptograma 1: ...
# Subcriptograma 2: ...
# Subcriptograma 3: ...
# Subcriptograma 4: ...
# Subcriptograma 5: ...
# Subcriptograma 6: ...

# %%
from collections import Counter

def analizar_frecuencia_subcriptograma(subcriptograma):
    """Analiza la frecuencia de letras en un subcriptograma."""
    frecuencia_letras = Counter(subcriptograma)
    longitud_subcriptograma = len(subcriptograma)
    frecuencia_relativa = {}
    if longitud_subcriptograma > 0:
        for letra, frecuencia in frecuencia_letras.items():
            frecuencia_relativa[letra] = frecuencia / longitud_subcriptograma
    return frecuencia_letras, frecuencia_relativa

def analizar_frecuencia_multiples_subcriptogramas(lista_subcriptogramas):
    """Analiza la frecuencia de letras en una lista de subcriptogramas."""
    resultados = {}
    for i, subcriptograma in enumerate(lista_subcriptogramas):
        frecuencias, frecuencias_relativas = analizar_frecuencia_subcriptograma(subcriptograma)
        resultados[i + 1] = {
            'frecuencias': frecuencias,
            'frecuencias_relativas': frecuencias_relativas
        }
    return resultados

# Subcriptogramas (reemplaza con tus 6 subcriptogramas reales)
# 'subcriptogramas_resultantes' FUE OBTENIDO DEL CÓDIGO ANTERIOR

# Obtener los subcriptogramas del código anterior
subcriptogramas = dividir_en_subcriptogramas(texto_cifrado_completo, longitud_clave_sugerida)

# Realizar el análisis de frecuencia para los múltiples subcriptogramas
resultados_analisis = analizar_frecuencia_multiples_subcriptogramas(subcriptogramas)

# Imprimir los resultados
for numero_subcriptograma, analisis in resultados_analisis.items():
    print(f"Análisis de frecuencia para el Subcriptograma {numero_subcriptograma}: '{''.join(subcriptogramas[numero_subcriptograma-1])}'\n")

    print("1. Contar la Frecuencia de las Letras:")
    for letra, frecuencia in sorted(analisis['frecuencias'].items()):
        print(f"  {letra}: {frecuencia}")

    print("\n2. Calcular las Frecuencias Relativas:")
    for letra, frecuencia_relativa in sorted(analisis['frecuencias_relativas'].items()):
        print(f"  {letra}: {frecuencia_relativa:.4f}")
    print("-" * 30)
# Out:
# Análisis de frecuencia para el Subcriptograma 1: '...'
#
# 1. Contar la Frecuencia de las Letras:
#   A: 4
#   B: 1
#   C: 65
#   D: 9
#   E: 14
#   F: 32
#   G: 67
#   H: 1
#   I: 5
#   J: 8
#   K: 26
#   L: 2
#   N: 41
#   O: 7
#   P: 27
#   Q: 36
#   R: 14
#   S: 3
#   T: 29
#   U: 30
#   V: 24
#   W: 20
#   X: 8
#   Z: 2
#
# 2. Calcular las Frecuencias Relativas:
#   A: 0.0084
#   B: 0.0021
#   C: 0.1368
#   D: 0.0189
#   E: 0.0295
#   F: 0.0674
#   G: 0.1411
#   H: 0.0021
#   I: 0.0105
#   J: 0.0168
#   K: 0.0547
#   L: 0.0042
#   N: 0.0863
#   O: 0.0147
#   P: 0.0568
#   Q: 0.0758
#   R: 0.0295
#   S: 0.0063
#   T: 0.0611
#   U: 0.0632
#   V: 0.0505
#   W: 0.0421
#   X: 0.0168
#   Z: 0.0042
# ------------------------------
# Análisis de frecuencia para el Subcriptograma 2: '...'
#
# 1. Contar la Frecuencia de las Letras:
#   A: 3
#   C: 24
#   D: 11
#   E: 34
#   F: 51
#   G: 13
#   H: 5
#   I: 29
#   J: 43
#   K: 24
#   L: 24
#   M: 3
#   P: 5
#   Q: 1
#   R: 65
#   S: 8
#   T: 17
#   U: 25
#   V: 60
#   W: 1
#   X: 2
#   Y: 3
#   Z: 24
#
# 2. Calcular las Frecuencias Relativas:
#   A: 0.0063
#   C: 0.0505
#   D: 0.0232
#   E: 0.0716
#   F: 0.1074
#   G: 0.0274
#   H: 0.0105
#   I: 0.0611
#   J: 0.0905
#   K: 0.0505
#   L: 0.0505
#   M: 0.0063
#   P: 0.0105
#   Q: 0.0021
#   R: 0.1368
#   S: 0.0168
#   T: 0.0358
#   U: 0.0526
#   V: 0.1263
#   W: 0.0021
#   X: 0.0042
#   Y: 0.0063
#   Z: 0.0505
# ------------------------------
# Análisis de frecuencia para el Subcriptograma 3: '...'
#
# 1. Contar la Frecuencia de las Letras:
#   A: 37
#   B: 25
#   C: 20
#   D: 11
#   G: 8
#   H: 3
#   I: 74
#   J: 12
#   K: 24
#   L: 21
#   M: 53
#   N: 3
#   O: 3
#   P: 4
#   Q: 25
#   R: 1
#   T: 30
#   U: 10
#   V: 30
#   W: 37
#   X: 10
#   Y: 4
#   Z: 30
#
# 2. Calcular las Frecuencias Relativas:
#   A: 0.0779
#   B: 0.0526
#   C: 0.0421
#   D: 0.0232
#   G: 0.0168
#   H: 0.0063
#   I: 0.1558
#   J: 0.0253
#   K: 0.0505
#   L: 0.0442
#   M: 0.1116
#   N: 0.0063
#   O: 0.0063
#   P: 0.0084
#   Q: 0.0526
#   R: 0.0021
#   T: 0.0632
#   U: 0.0211
#   V: 0.0632
#   W: 0.0779
#   X: 0.0211
#   Y: 0.0084
#   Z: 0.0632
# ------------------------------
# Análisis de frecuencia para el Subcriptograma 4: '...'
#
# 1. Contar la Frecuencia de las Letras:
#   A: 33
#   B: 3
#   C: 27
#   D: 34
#   E: 10
#   F: 2
#   G: 31
#   H: 47
#   I: 13
#   J: 12
#   K: 4
#   N: 6
#   O: 2
#   P: 61
#   Q: 15
#   R: 19
#   S: 29
#   T: 68
#   U: 1
#   V: 4
#   W: 3
#   X: 48
#   Y: 3
#
# 2. Calcular las Frecuencias Relativas:
#   A: 0.0695
#   B: 0.0063
#   C: 0.0568
#   D: 0.0716
#   E: 0.0211
#   F: 0.0042
#   G: 0.0653
#   H: 0.0989
#   I: 0.0274
#   J: 0.0253
#   K: 0.0084
#   N: 0.0126
#   O: 0.0042
#   P: 0.1284
#   Q: 0.0316
#   R: 0.0400
#   S: 0.0611
#   T: 0.1432
#   U: 0.0021
#   V: 0.0084
#   W: 0.0063
#   X: 0.1011
#   Y: 0.0063
# ------------------------------
# Análisis de frecuencia para el Subcriptograma 5: '...'
#
# 1. Contar la Frecuencia de las Letras:
#   A: 4
#   B: 19
#   C: 4
#   E: 39
#   F: 15
#   G: 29
#   H: 47
#   I: 14
#   J: 2
#   K: 28
#   L: 31
#   M: 19
#   N: 13
#   O: 8
#   R: 4
#   T: 64
#   U: 16
#   V: 16
#   W: 29
#   X: 66
#   Y: 3
#   Z: 5
#
# 2. Calcular las Frecuencias Relativas:
#   A: 0.0084
#   B: 0.0400
#   C: 0.0084
#   E: 0.0821
#   F: 0.0316
#   G: 0.0611
#   H: 0.0989
#   I: 0.0295
#   J: 0.0042
#   K: 0.0589
#   L: 0.0653
#   M: 0.0400
#   N: 0.0274
#   O: 0.0168
#   R: 0.0084
#   T: 0.1347
#   U: 0.0337
#   V: 0.0337
#   W: 0.0611
#   X: 0.1389
#   Y: 0.0063
#   Z: 0.0105
# ------------------------------
# Análisis de frecuencia para el Subcriptograma 6: '...'
#
# 1. Contar la Frecuencia de las Letras:
#   A: 13
#   B: 24
#   C: 38
#   D: 11
#   E: 5
#   F: 27
#   G: 42
#   H: 26
#   I: 16
#   J: 5
#   M: 1
#   N: 1
#   O: 70
#   P: 6
#   Q: 17
#   R: 29
#   S: 61
#   T: 3
#   U: 4
#   V: 3
#   W: 37
#   X: 4
#   Z: 31
#
# 2. Calcular las Frecuencias Relativas:
#   A: 0.0274
#   B: 0.0506
#   C: 0.0802
#   D: 0.0232
#   E: 0.0105
#   F: 0.0570
#   G: 0.0886
#   H: 0.0549
#   I: 0.0338
#   J: 0.0105
#   M: 0.0021
#   N: 0.0021
#   O: 0.1477
#   P: 0.0127
#   Q: 0.0359
#   R: 0.0612
#   S: 0.1287
#   T: 0.0063
#   U: 0.0084
#   V: 0.0063
#   W: 0.0781
#   X: 0.0084
#   Z: 0.0654
# ------------------------------

# %%
from collections import Counter


def encontrar_letras_mas_frecuentes(resultados_analisis, top_n=10):

    letras_mas_frecuentes = {}
    for numero_subcriptograma, analisis in resultados_analisis.items():
        frecuencias = analisis['frecuencias']
        sorted_frecuencias = sorted(frecuencias.items(), key=lambda item: item[1], reverse=True)
        letras_mas_frecuentes[numero_subcriptograma] = sorted_frecuencias[:top_n]
    return letras_mas_frecuentes

# Nombre del archivo de texto cifrado
nombre_de_archivo_cifrado = 'texto_cifrado.txt'
longitud_clave_sugerida = mcd_distancias

# Leer el texto cifrado
try:
    with open(nombre_de_archivo_cifrado, 'r') as archivo:
        texto_cifrado_completo = archivo.read()
except FileNotFoundError:
    print(f"Error: El archivo '{nombre_de_archivo_cifrado}' no fue encontrado.")
    exit()
except Exception as e:
    print(f"Ocurrió un error al leer el archivo: {e}")
    exit()

# Obtener los subcriptogramas
subcriptogramas = dividir_en_subcriptogramas(texto_cifrado_completo, longitud_clave_sugerida)

# Realizar el análisis de frecuencia
resultados_analisis = analizar_frecuencia_multiples_subcriptogramas(subcriptogramas)

# Encontrar las letras más frecuentes en cada subcriptograma
top_letras_por_subcriptograma = encontrar_letras_mas_frecuentes(resultados_analisis, top_n=10)

# Imprimir los resultados de las letras más frecuentes
print("\n--- Letras Más Frecuentes por Subcriptograma ---")
for numero_subcriptograma, top_letras in top_letras_por_subcriptograma.items():
    subcriptograma_str = ''.join(subcriptogramas[numero_subcriptograma-1])
    print(f"Subcriptograma {numero_subcriptograma}: '{subcriptograma_str[:20]}...'") # Mostrar solo los primeros 20 caracteres del subcriptograma
    print(f"  Las {len(top_letras)} letras más frecuentes son:")
    for letra, frecuencia in top_letras:
        print(f"    {letra}: {frecuencia} veces")
    print("-" * 30)
# Out:
# --- Letras Más Frecuentes por Subcriptograma ---
# Subcriptograma 1: 'CFCTZCTQTXPGEPSNGKGF...'
#   Las 10 letras más frecuentes son:
#     G: 67 veces
#     C: 65 veces
#     N: 41 veces
#     Q: 36 veces
#     F: 32 veces
#     U: 30 veces
#     T: 29 veces
#     P: 27 veces
#     K: 26 veces
#     V: 24 veces
# ------------------------------
# Subcriptograma 2: 'CFTRKVVEZFKKFULRCFER...'
#   Las 10 letras más frecuentes son:
#     R: 65 veces
#     V: 60 veces
#     F: 51 veces
#     J: 43 veces
#     E: 34 veces
#     I: 29 veces
#     U: 25 veces
#     C: 24 veces
#     K: 24 veces
#     Z: 24 veces
# ------------------------------
# Subcriptograma 3: 'ZZITMVKIUZWCUQMUJLKG...'
#   Las 10 letras más frecuentes son:
#     I: 74 veces
#     M: 53 veces
#     W: 37 veces
#     A: 37 veces
#     Z: 30 veces
#     T: 30 veces
#     V: 30 veces
#     Q: 25 veces
#     B: 25 veces
#     K: 24 veces
# ------------------------------
# Subcriptograma 4: 'TSIHCTWTXTSHEPHPPTXS...'
#   Las 10 letras más frecuentes son:
#     T: 68 veces
#     P: 61 veces
#     X: 48 veces
#     H: 47 veces
#     D: 34 veces
#     A: 33 veces
#     G: 31 veces
#     S: 29 veces
#     C: 27 veces
#     R: 19 veces
# ------------------------------
# Subcriptograma 5: 'WXXXWLTEMVXMKEXUKEFH...'
#   Las 10 letras más frecuentes son:
#     X: 66 veces
#     T: 64 veces
#     H: 47 veces
#     E: 39 veces
#     L: 31 veces
#     W: 29 veces
#     G: 29 veces
#     K: 28 veces
#     M: 19 veces
#     B: 19 veces
# ------------------------------
# Subcriptograma 6: 'SZRSWHNDWWJOSCZOFOOA...'
#   Las 10 letras más frecuentes son:
#     O: 70 veces
#     S: 61 veces
#     G: 42 veces
#     C: 38 veces
#     W: 37 veces
#     Z: 31 veces
#     R: 29 veces
#     F: 27 veces
#     H: 26 veces
#     B: 24 veces
# ------------------------------

# %%
ngramas("Esto es un texto de prueba",2)
# Out:
# ['Es',
#  'st',
#  'to',
#  'oe',
#  'es',
#  'su',
#  'un',
#  'nt',
#  'te',
#  'ex',
#  'xt',
#  'to',
#  'od',
#  'de',
#  'ep',
#  'pr',
#  'ru',
#  'ue',
#  'eb',
#  'ba']

# %%
def leer_frecuencias(archivo):
    """Lee un fichero con las frecuencias de los ngramas para el idioma Español"""
    return pd.read_csv(archivo, sep=" ", names=['letra', 'frecuencia'])

# %%
leer_frecuencias('spanish_monograms.txt')
# Out:
#    letra  frecuencia
# 0      E    10912000
# 1      A    10301872
# 2      O     7398419
# 3      S     6128524
# 4      N     5838540
# 5      I     5694616
# 6      R     5450913
# 7      L     4808679
# 8      D     4237020
# 9      C     3648080
# 10     T     3643515
# 11     U     3292410
# 12     P     2266539
# 13     M     2152702
# 14     B     1042859
# 15     G      964043
# 16     V      811441
# 17     Q      686200
# 18     H      670756
# 19     F      652415
# 20     Y      651259
# 21     J      374173
# 22     Z      344877
# 23     Ñ      178384
# 24     X      153120
# 25     K       64167
# 26     W       26492

# %% [markdown]
# ## Definimos el alfabeto y hacemos asociaciones

# %%
def descifrar_vigenere(texto_cifrado, clave):

    texto_plano = ""
    clave = clave.upper()
    longitud_clave = len(clave)
    indice_clave = 0

    for letra_cifrada in texto_cifrado:
        if 'A' <= letra_cifrada <= 'Z':
            desplazamiento = ord(clave[indice_clave % longitud_clave]) - ord('A')
            posicion_cifrada = ord(letra_cifrada) - ord('A')
            posicion_plana = (posicion_cifrada - desplazamiento + 26) % 26
            letra_plana = chr(posicion_plana + ord('A'))
            texto_plano += letra_plana
            indice_clave += 1
        elif 'a' <= letra_cifrada <= 'z':
            desplazamiento = ord(clave[indice_clave % longitud_clave]) - ord('A')
            posicion_cifrada = ord(letra_cifrada) - ord('a')
            posicion_plana = (posicion_cifrada - desplazamiento + 26) % 26
            letra_plana = chr(posicion_plana + ord('a'))
            texto_plano += letra_plana
            indice_clave += 1
        else:
            # Mantener caracteres no alfabéticos sin cambios
            texto_plano += letra_cifrada

    return texto_plano

if __name__ == "__main__":
    nombre_archivo = "texto_cifrado.txt"
    try:
        with open(nombre_archivo, 'r') as archivo:
            texto_cifrado_leido = archivo.read()
    except FileNotFoundError:
        print(f"Error: El archivo '{nombre_archivo}' no se encontró.")
        texto_cifrado_leido = ""
    except Exception as e:
        print(f"Error al leer el archivo '{nombre_archivo}': {e}")
        texto_cifrado_leido = ""

    if texto_cifrado_leido:
        clave_usuario = input("INGRESE CLAVE DE DESCIFRADO: ")
        texto_descifrado = descifrar_vigenere(texto_cifrado_leido, clave_usuario)
        print("\nTexto Descifrado:")
        print(texto_descifrado)
# Out:
# INGRESE CLAVE DE DESCIFRADO: CRIPTO
#
# Texto Descifrado:
# ...
